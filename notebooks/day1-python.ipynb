# %% [markdown]
# # Heading 1
# ## Heading 2
# ##### Heading 5
#
# * bullet 1
# * bullet 2
#     * bullet 2.1
#     - bullet 2.2
#
# $\frac{a}{b}$
#
# <a href="https://pad.carpentries.org/2025-06-07-aas">Etherpad</a>

# %%
1
# Out:
# 1

# %%
2
# Out:
# 2

# %%
1+2
# Out:
# 3

# %%
1.
# Out:
# 1.0

# %%
3.
# Out:
# 3.0

# %%
1.*2
# Out:
# 2.0

# %%
1/2
# Out:
# 0.5

# %%
2-3
# Out:
# -1

# %%
2**3
# Out:
# 8

# %%
import math

# %%
help(math)
# Out:
# Help on module math:
#
# NAME
#     math
#
# MODULE REFERENCE
#     https://docs.python.org/3.9/library/math
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#         The result is between 0 and pi.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
# ...

# %%
dir(math)
# Out:
# ['__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
math.__file__
# Out:
# '/Users/bostroem/opt/anaconda3/lib/python3.9/lib-dynload/math.cpython-39-darwin.so'

# %%
math.acos(0.3)
# Out:
# 1.266103672779499

# %%
math.log2(8)
# Out:
# 3.0

# %%
math.acos(2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/6l/54htg8p52b762n_6mhsb13v80000gn/T/ipykernel_5620/1429870391.py in <module>
# ----> 1 math.acos(2)
#
# ValueError: math domain error

# %%
math.acos?

# %%
'star'
# Out:
# 'star'

# %%
'shooting'+'star'
# Out:
# 'shootingstar'

# %%
'star'*3
# Out:
# 'starstarstar'

# %%
'star'[0]
# Out:
# 's'

# %%
'star'[2]
# Out:
# 'a'

# %%
'star'[0:2]
# Out:
# 'st'

# %%
'star'[0:1]+'star'[1:2]
# Out:
# 'st'

# %%
'star'[-1]
# Out:
# 'r'

# %% [markdown]
# # Variables

# %%
y = 'star'
print(y[0])
# Out:
# s

# %%
y = 3
z = 10
y+z
# Out:
# 13

# %% [markdown]
# # Collections

# %%
my_list = [1, 2, 3]

# %%
my_list2 = ['a', 1, 'b', 'train']

# %%
my_list*3
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
my_list2[1]
# Out:
# 1

# %%
my_list2[1:3]
# Out:
# [1, 'b']

# %%
my_list2[-1]
# Out:
# 'train'

# %%
my_list2[:3]
# Out:
# ['a', 1, 'b']

# %%
my_list2[1::2]
# Out:
# [1, 'train']

# %%
import numpy as np

# %%
my_array = np.array(my_list)
my_array
# Out:
# array([1, 2, 3])

# %%
type(my_array)
# Out:
# numpy.ndarray

# %%
type(my_list)
# Out:
# list

# %% [markdown]
# Exercise:
# 1. Create you own numpy array using only numbers
# 2. Experiment with different arithnmic operations
# 3. How do arrays behave differently from list?
# 4. Does the numpy module have a mean function? how can you tell
# 5. If it does, find the mean of your array

# %% [markdown]
# #### Solution

# %%
my_array = np.array([1,   2,   3,  4])
print(my_array*3)
print(my_array**2)
# Out:
# [ 3  6  9 12]
# [ 1  4  9 16]

# %%
np.mean(my_array)
# Out:
# nan

# %%
np.nanmean(my_array)
# Out:
# 2.5

# %%
np.mean?

# %%
np.isnan(my_array)
np.isfinite

# %%
np.nanmean?

# %%
my_array.mean()
# Out:
# 2.5

# %%
my_array.size
# Out:
# 4

# %%
my_array.mean()
# Out:
# <function ndarray.mean>

# %%
np.__file__
# Out:
# '/Users/bostroem/opt/anaconda3/lib/python3.9/site-packages/numpy/__init__.py'

# %% [markdown]
# # Multi D arrays

# %%
my_2d_arr = np.vstack([my_array, 2*my_array, 3*my_array])

# %%
my_2d_arr
# Out:
# array([[ 1,  2,  3,  4],
#        [ 2,  4,  6,  8],
#        [ 3,  6,  9, 12]])

# %%
my_2d_arr.shape
# Out:
# (3, 4)

# %%
my_2d_arr.size
# Out:
# 12

# %%
np.hstack([my_array, 2*my_array, 3*my_array])
# Out:
# array([ 1,  2,  3,  4,  2,  4,  6,  8,  3,  6,  9, 12])

# %%
my_2d_arr[1, 2]
# Out:
# 6

# %%
my_2d_arr[0:2, 2:4]
# Out:
# array([[3, 4],
#        [6, 8]])

# %%
np.mean(my_2d_arr, axis=0)
# Out:
# array([2., 4., 6., 8.])

# %%
my_2d_arr.mean(axis=0)
# Out:
# array([2., 4., 6., 8.])

# %% [markdown]
# # Loops

# %%
my_favorite_stars = ['sirius', 'deneb', 'altair']
for star in my_favorite_stars:
    print(star)
# Out:
# sirius
# deneb
# altair

# %% [markdown]
# # Conditional statements

# %%
if condition:
    do a
elif condition:
    do b
else: 
    do c

# %%
==
!=
>
<
>=
<=
in
not

and
or

&
|

(condition 1) & (condition 2)
# Out:
#   File "/var/folders/6l/54htg8p52b762n_6mhsb13v80000gn/T/ipykernel_5620/2390708615.py", line 1
#     ==
#     ^
# SyntaxError: invalid syntax

# %%
constellation = 'cygnus'
if constellation =='cygnus':
    print('cygnus is my favorite constellation')
else: #comment
    print(f'{constellation} is not my favorite constellation')
# Out:
# cygnus is my favorite constellation

# %%
'%s'
'{}'.format(constellation)

# %%
constellation = 'lyra'
if constellation =='cygnus':
    print('cygnus is my favorite constellation')
else: #comment
    print(f'{constellation} is not my favorite constellation')
# Out:
# lyra is not my favorite constellation

# %% [markdown]
# # Exercise:
# Loop throught your list of favorite stars. I fthe name of the star has 6 letters, then print the name of the star. Otherwise, print a message that the number of letters in the star name was the wrong size

# %% [markdown]
# # Solution

# %%
for star in my_favorite_stars:
    if len(star)==6:
        print(star)
    else:
        print(f'length of name {star} is not 6')
# Out:
# sirius
# length of name deneb is not 6
# altair

# %%
my_list = [1, 2, 5, 7, 9, 4, 5, 4]
#find the total
total = 0
for num in my_list:
    total = total+num
#calculate the mean
mean = total/len(my_list)
#Find the median
sorted_list = sorted(my_list)
if len(my_list)%2==1:
    median_indx = int(len(my_list)/2)
    median = sorted_list[median_indx]
else:
    median_indx = int(len(my_list)/2)
    median = (sorted_list[median_indx]+sorted_list[median_indx-1])/2
print(mean, median)
print(np.mean(my_list), np.median(my_list))
# Out:
# 4.625 4.5
# 4.625 4.5

# %%
len=2

# %%
len(my_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/6l/54htg8p52b762n_6mhsb13v80000gn/T/ipykernel_5620/2292191500.py in <module>
# ----> 1 len(my_list)
#
# TypeError: 'int' object is not callable

# %%
del len

# %%
len(my_list)
# Out:
# 8

# %%
def calc_total(my_list):
    """
    find the total
    """
    total = 0
    for num in my_list:
        total = total+num
    return total

# %%
help(calc_total)
# Out:
# Help on function calc_total in module __main__:
#
# calc_total(my_list)
#     find the total

# %%
def calc_mean(my_list):
    """
    calculate the mean
    """
    total = calc_total(my_list)
    mean = total/len(my_list)
    return mean

def calc_median(my_list):
    """
    Find the median
    """
    sorted_list = sorted(my_list)
    if len(my_list)%2==1:
        median_indx = int(len(my_list)/2)
        median = sorted_list[median_indx]
    else:
        median_indx = int(len(my_list)/2)
        median = (sorted_list[median_indx]+sorted_list[median_indx-1])/2
    return median

# %%
mean = calc_mean(my_list)
median = calc_median(my_list)
print(mean, median)
# Out:
# 4.625 4.5

# %%
my_list3 = [1, 4, 7, 8]
mean = calc_mean(my_list3)
median = calc_median(my_list3)
print(mean, median)
# Out:
# 5.0 5.5

# %% [markdown]
# # Exercise:
# write a function that takes a distance in parsecs and converts it to a distance in megaparsecs

# %% [markdown]
# # Solution

# %%
def convert_to_megaparsecs(dist_pc):
    """
    Takes a distance in parsecs and converts it to megaparsecs
    Inputs:
        dist_pc: distance in parsecs
    Outputs:
        dist_mpc: distance in megaparsecs
    """
    dist_mpc = dist_pc/10**6
    return dist_mpc

# %%
convert_to_megaparsecs(10**6)
# Out:
# 1.0

# %%
import astropy.units as u

# %%
dist = (10**6 * u.parsec).to(u.Mpc)

# %%
dist.value
# Out:
# 1.0

# %% [markdown]
# # Hubble Diagram

# %%
from astropy.table import Table

# %%
# !cat hubble_data.dat
# Out:
# M101 2011fe 13.310 0.117 29.135 0.045 -19.389 0.125 241
# N1015 2009ig 17.015 0.123 32.497 0.081 -19.047 0.147 2629
# N1309 2002fk 16.756 0.116 32.523 0.055 -19.331 0.128 2136
# N1365 2012fr 15.482 0.125 31.307 0.057 -19.390 0.137 1636
# N1448 2001el 15.765 0.116 31.311 0.045 -19.111 0.125 1168
# N2442 2015F 15.840 0.142 31.511 0.053 -19.236 0.152 1466
# N3021 1995al 16.527 0.117 32.498 0.090 -19.535 0.147 1541
# N3370 1994ae 16.476 0.115 32.072 0.049 -19.161 0.125 1279
# N3447 2012ht 16.265 0.124 31.908 0.043 -19.207 0.131 1067
# N3972 2011by 16.048 0.116 31.587 0.070 -19.103 0.136 852
# N3982 1998aq 15.795 0.115 31.737 0.069 -19.507 0.134 1109
# N4038 2007sr 15.797 0.114 31.290 0.112 -19.058 0.160 1642
# N4424 2012cg 15.110 0.109 31.080 0.292 -19.534 0.311 437
# N4536 1981B 15.177 0.124 30.906 0.053 -19.293 0.135 1808
# N4639 1990N 15.983 0.115 31.532 0.071 -19.113 0.135 1018
# N5584 2007af 16.265 0.115 31.786 0.046 -19.085 0.124 1638
# ...

# %%
filename='hubble_data.dat'
tbdata = Table.read(filename, format='ascii',
                   names=['galaxy',
                         'supernova', 
                         'm',
                         'sig_m',
                         'dist_mod',
                         'sig_dist_mod',
                         'M',
                         'sig_M',
                         'velocity'])

# %%
tbdata
# Out:
# <Table length=19>
# galaxy supernova    m     sig_m  dist_mod sig_dist_mod    M     sig_M  velocity
#  str5     str6   float64 float64 float64    float64    float64 float64  int64
# ------ --------- ------- ------- -------- ------------ ------- ------- --------
#   M101    2011fe   13.31   0.117   29.135        0.045 -19.389   0.125      241
#  N1015    2009ig  17.015   0.123   32.497        0.081 -19.047   0.147     2629
#  N1309    2002fk  16.756   0.116   32.523        0.055 -19.331   0.128     2136
#  N1365    2012fr  15.482   0.125   31.307        0.057  -19.39   0.137     1636
#  N1448    2001el  15.765   0.116   31.311        0.045 -19.111   0.125     1168
#  N2442     2015F   15.84   0.142   31.511        0.053 -19.236   0.152     1466
#  N3021    1995al  16.527   0.117   32.498         0.09 -19.535   0.147     1541
#  N3370    1994ae  16.476   0.115   32.072        0.049 -19.161   0.125     1279
# ...

# %%
tbdata[0]
# Out:
# <Row index=0>
# galaxy supernova    m     sig_m  dist_mod sig_dist_mod    M     sig_M  velocity
#  str5     str6   float64 float64 float64    float64    float64 float64  int64
# ------ --------- ------- ------- -------- ------------ ------- ------- --------
#   M101    2011fe   13.31   0.117   29.135        0.045 -19.389   0.125      241

# %%
tbdata['supernova']
# Out:
# <Column name='supernova' dtype='str6' length=19>
# 2011fe
# 2009ig
# 2002fk
# 2012fr
# 2001el
#  2015F
# 1995al
# 1994ae
# 2012ht
# 2011by
# 1998aq
# 2007sr
# 2012cg
#  1981B
#  1990N
# 2007af
# 2005cf
# 2013dy
# 2003du

# %%
tbdata.show_in_notebook()
# Out:
# <i>Table length=19</i>
# <table id="table140168440162384-807462" class="table-striped table-bordered table-condensed">
# <thead><tr><th>idx</th><th>galaxy</th><th>supernova</th><th>m</th><th>sig_m</th><th>dist_mod</th><th>sig_dist_mod</th><th>M</th><th>sig_M</th><th>velocity</th></tr></thead>
# <tr><td>0</td><td>M101</td><td>2011fe</td><td>13.31</td><td>0.117</td><td>29.135</td><td>0.045</td><td>-19.389</td><td>0.125</td><td>241</td></tr>
# <tr><td>1</td><td>N1015</td><td>2009ig</td><td>17.015</td><td>0.123</td><td>32.497</td><td>0.081</td><td>-19.047</td><td>0.147</td><td>2629</td></tr>
# <tr><td>2</td><td>N1309</td><td>2002fk</td><td>16.756</td><td>0.116</td><td>32.523</td><td>0.055</td><td>-19.331</td><td>0.128</td><td>2136</td></tr>
# <tr><td>3</td><td>N1365</td><td>2012fr</td><td>15.482</td><td>0.125</td><td>31.307</td><td>0.057</td><td>-19.39</td><td>0.137</td><td>1636</td></tr>
# ...

# %%
tbdata.show_in_browser()

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
plt.plot(tbdata['dist_mod'], tbdata['velocity'], 'o')
plt.xlabel('Distance Modulus')
plt.ylabel(r'Velocity ($km~s^{-1}$)')
# Out:
# Text(0, 0.5, 'Velocity ($km~s^{-1}$)')

# %% [markdown]
# # Exercise
# write a function to convert distance modulus into distance

# %%
def find_distance(dist_mod):
    """
    Find a distance give a distance modulus
    Input:
        dist_mod: distance modulus - can be single number of numpy array
    Output:
        dist: distance in parsecs
    """
    dist = 10**((dist_mod+5)/5)
    return dist

# %%
dist_pc = find_distance(tbdata['dist_mod'])

# %%
dist_mpc = convert_to_megaparsecs(dist_pc)

# %%
dist_mpc
# Out:
# <Column name='dist_mod' dtype='float64' length=19>
# 6.7142885292595365
# 31.579118286322494
#  31.95950174814766
# 18.255763461880687
# 18.289422812817623
# 20.053953334298246
# 31.593664356825094
# 25.965697902737876
# 24.076868456124497
# 20.768254637773932
# 22.253585780465095
# 18.113400926196025
#  16.44371723214929
# 15.177491558612479
# 20.248833065305558
# 22.761453931416472
# 28.353064117606827
# 19.943436742573407
#  38.35305824568585

# %% [markdown]
# # Exercise:
# Plot velocity vs distance in Mpc

# %%
plt.plot(dist_mpc, tbdata['velocity'], 'ro')

# %% [markdown]
# # Fit data

# %%
hubble_flow_galaxies = dist_mpc >23
tbdata['velocity'][hubble_flow_galaxies]
# Out:
# <Column name='velocity' dtype='int64' length=7>
# 2629
# 2136
# 1541
# 1279
# 1067
# 1904
# 1914

# %%
dist_mpc[hubble_flow_galaxies]
# Out:
# <Column name='dist_mod' dtype='float64' length=7>
# 31.579118286322494
#  31.95950174814766
# 31.593664356825094
# 25.965697902737876
# 24.076868456124497
# 28.353064117606827
#  38.35305824568585

# %%
fit = np.polyfit(dist_mpc[hubble_flow_galaxies], 
                 tbdata['velocity'][hubble_flow_galaxies], 
                 1)
print(fit)
# Out:
# [  66.66645726 -236.47911969]

# %%
np.polyval(fit, dist_mpc)
# Out:
# <Column name='dist_mod' dtype='float64' length=19>
#   211.138709562734
# 1868.7888197872921
# 1894.1476375866773
#  980.5679548516134
#    982.81190453218
# 1100.4469031227534
# 1869.7585547747244
# 1494.5619697143422
# 1368.6404021442013
#  1148.066840440188
# 1247.0886055782576
#  971.0771489512638
#  859.7652523278603
#  775.3504725841444
# 1113.4388443803864
# 1280.9463759563137
# 1653.7192174368924
# 1093.0791534842392
# 2320.3833985558686

# %%
plt.plot(dist_mpc, tbdata['velocity'], 'o', label='Data')
plt.plot(dist_mpc, np.polyval(fit, dist_mpc), label='Fit')
plt.xlabel('Distance (Mpc)')
plt.ylabel(r'Velocity ($\rm km~s^{-1}$)')
plt.legend()
plt.title('Hubble Diagram')
plt.savefig('hubble_diagram.pdf')
# Out:
# Text(0.5, 1.0, 'Hubble Diagram')

# %%
plt.style.use('fivethirtyeight')

# %%
plt.plot(dist_mpc, tbdata['velocity'], 'o', label='Data')
plt.plot(dist_mpc, np.polyval(fit, dist_mpc), label='Fit')
plt.xlabel('Distance (Mpc)')
plt.ylabel(r'Velocity ($\rm km~s^{-1}$)')
plt.legend()
plt.title('Hubble Diagram')
plt.savefig('hubble_diagram.pdf')

# %%
plt.style.use('default')

# %%
plt.style.use('az-paper-onecol')

# %%
plt.plot(dist_mpc, tbdata['velocity'], 'o', label='Data')
plt.plot(dist_mpc, np.polyval(fit, dist_mpc), label='Fit')
plt.xlabel('Distance (Mpc)')
plt.ylabel(r'Velocity ($\rm km~s^{-1}$)')
plt.legend()
plt.title('Hubble Diagram')
plt.savefig('hubble_diagram.pdf')

# %%
plt.rcParams['font.family'] =
# Out:
# ['sans-serif']

# %%
fig, (ax1, ax2) = plt.subplots(1,2)
ax1.plot(dist_mpc, tbdata['velocity'], 'o', label='Data')
ax2.plot(dist_mpc, np.polyval(fit, dist_mpc), label='Fit')
ax1.set_title('Data')
ax2.set_title('Fit')
ax1.set_xlabel('Distance (Mpc)')
ax2.set_xlabel('Distance (Mpc)')

fig.suptitle('Hubble Analysis')
plt.tight_layout()
